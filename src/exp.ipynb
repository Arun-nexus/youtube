# %%
import pandas as pd
import pickle

# %%
y = pd.read_csv(r"C:\Users\Arun\OneDrive\Documents\youtube\data\train_y.csv")

# %%
y_true = pd.read_csv(r"C:\Users\Arun\OneDrive\Documents\youtube\data\test_y.csv")

# %%
with open(r"C:\Users\Arun\OneDrive\Documents\youtube\model\model.pkl","rb") as f:
    model = pickle.load(f)

# %%
pred = model.predict(y)

# %%
pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(3682,))
